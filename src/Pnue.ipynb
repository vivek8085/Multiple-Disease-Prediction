# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("paultimothymooney/chest-xray-pneumonia")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'chest-xray-pneumonia' dataset.
# Path to dataset files: /kaggle/input/chest-xray-pneumonia

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input

# %%
train_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray/train'
val_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray/val'
test_dir = '/kaggle/input/chest-xray-pneumonia/chest_xray/test'

# %%
classes = os.listdir(train_dir)
num_classes = len(classes)

# Display the class names
print(f'Number of Classes: {num_classes}')
print(f'Classes: {classes}')
# Out:
# Number of Classes: 2
# Classes: ['PNEUMONIA', 'NORMAL']

# %%
plt.figure(figsize=(12, 10))
for i in range(5):
  class_path = os.path.join(train_dir, classes[0])
  img_name = os.listdir(class_path)[i]
  img_path = os.path.join(class_path, img_name)
  img = plt.imread(img_path)

  plt.subplot(1, 5, i+1)
  plt.imshow(img)
  plt.title(f'{classes[0]} \n shape: {img.shape}')
  plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(12, 10))
for i in range(5):
  class_path = os.path.join(train_dir, classes[1])
  img_name = os.listdir(class_path)[i]
  img_path = os.path.join(class_path, img_name)
  img = plt.imread(img_path)

  plt.subplot(1, 5, i+1)
  plt.imshow(img)
  plt.title(f'{classes[1]} \n shape: {img.shape}')
  plt.axis('off')
plt.show()

# %%
# Preprocessing
# Image dimensions and batch size
img_width, img_height = 150, 150
batch_size = 32 # there will be 32 images in a batch!

# Data generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = 'binary',
    shuffle = True
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = 'binary',
    shuffle = True
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size = (img_width, img_height),
    batch_size = batch_size,
    class_mode = 'binary',
    shuffle = True
)
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
# map the indices
class_mapping = train_generator.class_indices
print(class_mapping)
# Extract the class names
class_names = list(class_mapping.keys())
print("Class Names:", class_names)
# Out:
# {'NORMAL': 0, 'PNEUMONIA': 1}
# Class Names: ['NORMAL', 'PNEUMONIA']

# %%
# Let's build the CNN Model
model = Sequential([
    Input(shape=(img_width, img_height, 3)),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(256, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(512, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
]
)

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 15, 15, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 7, 7, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 5, 5, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,618,177 (9.99 MB)
#  Trainable params: 2,618,177 (9.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    epochs = 25,
    validation_data = val_generator,
    validation_steps = val_generator.samples // batch_size
)
# Out:
# Epoch 1/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 80s 441ms/step - accuracy: 0.8096 - loss: 0.4376 - val_accuracy: 0.6250 - val_loss: 1.6721
# Epoch 2/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 47s 287ms/step - accuracy: 0.9268 - loss: 0.1910 - val_accuracy: 0.6875 - val_loss: 1.4493
# Epoch 3/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 46s 282ms/step - accuracy: 0.9528 - loss: 0.1200 - val_accuracy: 0.7500 - val_loss: 0.5003
# Epoch 4/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 47s 288ms/step - accuracy: 0.9674 - loss: 0.0894 - val_accuracy: 0.7500 - val_loss: 0.8617
# Epoch 5/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 83s 293ms/step - accuracy: 0.9724 - loss: 0.0758 - val_accuracy: 0.8125 - val_loss: 0.8062
# Epoch 6/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 48s 294ms/step - accuracy: 0.9793 - loss: 0.0531 - val_accuracy: 0.8125 - val_loss: 0.1752
# Epoch 7/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 47s 290ms/step - accuracy: 0.9870 - loss: 0.0363 - val_accuracy: 0.8125 - val_loss: 1.0026
# Epoch 8/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 47s 289ms/step - accuracy: 0.9910 - loss: 0.0275 - val_accuracy: 0.9375 - val_loss: 0.3965
# Epoch 9/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 48s 293ms/step - accuracy: 0.9900 - loss: 0.0252 - val_accuracy: 0.8750 - val_loss: 0.9861
# Epoch 10/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 48s 293ms/step - accuracy: 0.9900 - loss: 0.0279 - val_accuracy: 0.8750 - val_loss: 0.1650
# Epoch 11/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 47s 289ms/step - accuracy: 0.9902 - loss: 0.0295 - val_accuracy: 0.7500 - val_loss: 1.3736
# Epoch 12/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 46s 283ms/step - accuracy: 0.9916 - loss: 0.0248 - val_accuracy: 0.6250 - val_loss: 2.5193
# Epoch 13/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 48s 292ms/step - accuracy: 0.9973 - loss: 0.0076 - val_accuracy: 0.8750 - val_loss: 0.9515
# Epoch 14/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 82s 291ms/step - accuracy: 0.9956 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 15/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 47s 291ms/step - accuracy: 0.9952 - loss: 0.0132 - val_accuracy: 0.8750 - val_loss: 0.9601
# Epoch 16/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 47s 288ms/step - accuracy: 0.9889 - loss: 0.0328 - val_accuracy: 0.9375 - val_loss: 0.2285
# Epoch 17/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 48s 291ms/step - accuracy: 0.9935 - loss: 0.0147 - val_accuracy: 0.9375 - val_loss: 0.4245
# Epoch 18/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 48s 293ms/step - accuracy: 0.9992 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 2.8864e-04
# Epoch 19/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 47s 291ms/step - accuracy: 0.9952 - loss: 0.0145 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 20/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 47s 290ms/step - accuracy: 0.9919 - loss: 0.0208 - val_accuracy: 0.8750 - val_loss: 0.7603
# Epoch 21/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 46s 283ms/step - accuracy: 0.9946 - loss: 0.0206 - val_accuracy: 0.8750 - val_loss: 1.4230
# Epoch 22/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 48s 292ms/step - accuracy: 0.9941 - loss: 0.0157 - val_accuracy: 0.7500 - val_loss: 1.3771
# Epoch 23/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 48s 292ms/step - accuracy: 0.9979 - loss: 0.0062 - val_accuracy: 0.9375 - val_loss: 0.5349
# Epoch 24/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 48s 293ms/step - accuracy: 0.9939 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0431
# Epoch 25/25
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 47s 289ms/step - accuracy: 0.9975 - loss: 0.0075 - val_accuracy: 0.8125 - val_loss: 0.8216

# %%
# Evaluate the model - plotting training and validation acc
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Evaluate the model - plotting training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Evaluate the model using test data
test_loss, test_acc = model.evaluate(test_generator, steps=test_generator.samples // batch_size)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 324ms/step - accuracy: 0.7516 - loss: 3.2220
# Test Accuracy: 0.7516

# %%
model.save('Pnue.keras')

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# Load the model
model = load_model('Pnue.keras')

# Predict on new image - create a function
def predict(img_path):
  img = image.load_img(img_path, target_size=(150, 150))
  img_array = image.img_to_array(img)
  img_array = np.expand_dims(img_array, axis=0)
  img_array /= 255.0

  prediction = model.predict(img_array)
  if prediction[0] > 0.5:
    predicted_class = class_names[1]
  else:
    predicted_class = class_names[0]

  plt.imshow(img)
  plt.title(f'Predicted: {predicted_class}')
  plt.axis('off')
  plt.show()

# %%
os.listdir('/kaggle/input/chest-xray-pneumonia/chest_xray/test/NORMAL/')
# Out:
# ['NORMAL2-IM-0336-0001.jpeg',
#  'IM-0101-0001.jpeg',
#  'NORMAL2-IM-0337-0001.jpeg',
#  'NORMAL2-IM-0198-0001.jpeg',
#  'IM-0013-0001.jpeg',
#  'IM-0103-0001.jpeg',
#  'NORMAL2-IM-0139-0001.jpeg',
#  'NORMAL2-IM-0313-0001.jpeg',
#  'NORMAL2-IM-0340-0001.jpeg',
#  'NORMAL2-IM-0378-0001.jpeg',
#  'IM-0009-0001.jpeg',
#  'NORMAL2-IM-0051-0001.jpeg',
#  'NORMAL2-IM-0322-0001.jpeg',
#  'IM-0091-0001.jpeg',
#  'IM-0070-0001.jpeg',
#  'NORMAL2-IM-0274-0001.jpeg',
#  'IM-0059-0001.jpeg',
#  'IM-0067-0001.jpeg',
#  'NORMAL2-IM-0210-0001.jpeg',
#  'NORMAL2-IM-0073-0001.jpeg',
#  'NORMAL2-IM-0290-0001.jpeg',
#  'NORMAL2-IM-0135-0001.jpeg',
#  'IM-0097-0001.jpeg',
#  'NORMAL2-IM-0092-0001.jpeg',
#  'NORMAL2-IM-0366-0001.jpeg',
#  'IM-0015-0001.jpeg',
#  'NORMAL2-IM-0330-0001.jpeg',
#  'NORMAL2-IM-0294-0001.jpeg',
#  'NORMAL2-IM-0027-0001.jpeg',
#  'NORMAL2-IM-0348-0001.jpeg',
#  'IM-0041-0001.jpeg',
#  'NORMAL2-IM-0237-0001.jpeg',
#  'NORMAL2-IM-0282-0001.jpeg',
#  'NORMAL2-IM-0259-0001.jpeg',
#  'IM-0084-0001.jpeg',
#  'NORMAL2-IM-0201-0001.jpeg',
#  'NORMAL2-IM-0120-0001.jpeg',
#  'NORMAL2-IM-0357-0001.jpeg',
#  'NORMAL2-IM-0035-0001.jpeg',
#  'NORMAL2-IM-0098-0001.jpeg',
#  'NORMAL2-IM-0315-0001.jpeg',
#  'NORMAL2-IM-0278-0001.jpeg',
#  'NORMAL2-IM-0287-0001.jpeg',
#  'NORMAL2-IM-0345-0001.jpeg',
#  'IM-0029-0001.jpeg',
#  'NORMAL2-IM-0052-0001.jpeg',
#  'IM-0081-0001.jpeg',
#  'IM-0110-0001.jpeg',
#  'IM-0035-0001.jpeg',
#  'NORMAL2-IM-0374-0001.jpeg',
#  'NORMAL2-IM-0276-0001.jpeg',
#  'NORMAL2-IM-0301-0001.jpeg',
#  'NORMAL2-IM-0283-0001.jpeg',
#  'NORMAL2-IM-0222-0001.jpeg',
#  'NORMAL2-IM-0346-0001.jpeg',
#  'NORMAL2-IM-0289-0001.jpeg',
#  'NORMAL2-IM-0111-0001.jpeg',
#  'NORMAL2-IM-0112-0001.jpeg',
#  'NORMAL2-IM-0309-0001.jpeg',
#  'IM-0105-0001.jpeg',
#  'NORMAL2-IM-0041-0001.jpeg',
#  'NORMAL2-IM-0376-0001.jpeg',
#  'NORMAL2-IM-0351-0001.jpeg',
#  'IM-0021-0001.jpeg',
#  'NORMAL2-IM-0033-0001.jpeg',
#  'NORMAL2-IM-0246-0001-0002.jpeg',
#  'NORMAL2-IM-0207-0001.jpeg',
#  'IM-0033-0001-0002.jpeg',
#  'NORMAL2-IM-0019-0001.jpeg',
#  'NORMAL2-IM-0132-0001.jpeg',
#  'NORMAL2-IM-0302-0001.jpeg',
#  'NORMAL2-IM-0171-0001.jpeg',
#  'NORMAL2-IM-0012-0001.jpeg',
#  'NORMAL2-IM-0028-0001.jpeg',
#  'NORMAL2-IM-0281-0001.jpeg',
#  'NORMAL2-IM-0327-0001.jpeg',
#  'IM-0022-0001.jpeg',
#  'NORMAL2-IM-0030-0001.jpeg',
#  'NORMAL2-IM-0007-0001.jpeg',
#  'IM-0003-0001.jpeg',
#  'IM-0107-0001.jpeg',
#  'NORMAL2-IM-0310-0001.jpeg',
#  'NORMAL2-IM-0058-0001.jpeg',
#  'NORMAL2-IM-0307-0001.jpeg',
#  'IM-0017-0001.jpeg',
#  'NORMAL2-IM-0096-0001.jpeg',
#  'NORMAL2-IM-0362-0001.jpeg',
#  'NORMAL2-IM-0326-0001.jpeg',
#  'NORMAL2-IM-0332-0001.jpeg',
#  'IM-0006-0001.jpeg',
#  'NORMAL2-IM-0252-0001.jpeg',
#  'NORMAL2-IM-0081-0001.jpeg',
#  'NORMAL2-IM-0145-0001.jpeg',
#  'NORMAL2-IM-0297-0001.jpeg',
#  'IM-0043-0001.jpeg',
#  'NORMAL2-IM-0199-0001.jpeg',
#  'IM-0061-0001.jpeg',
#  'IM-0111-0001.jpeg',
#  'NORMAL2-IM-0321-0001.jpeg',
#  'NORMAL2-IM-0246-0001-0001.jpeg',
#  'NORMAL2-IM-0059-0001.jpeg',
#  'NORMAL2-IM-0206-0001.jpeg',
#  'NORMAL2-IM-0311-0001.jpeg',
#  'NORMAL2-IM-0319-0001.jpeg',
#  'NORMAL2-IM-0217-0001.jpeg',
#  'IM-0102-0001.jpeg',
#  'IM-0071-0001.jpeg',
#  'NORMAL2-IM-0374-0001-0002.jpeg',
#  'IM-0001-0001.jpeg',
#  'NORMAL2-IM-0232-0001.jpeg',
#  'NORMAL2-IM-0286-0001.jpeg',
#  'IM-0031-0001.jpeg',
#  'NORMAL2-IM-0305-0001.jpeg',
#  'NORMAL2-IM-0246-0001.jpeg',
#  'NORMAL2-IM-0273-0001.jpeg',
#  'NORMAL2-IM-0360-0001.jpeg',
#  'IM-0050-0001.jpeg',
#  'NORMAL2-IM-0129-0001.jpeg',
#  'NORMAL2-IM-0272-0001.jpeg',
#  'NORMAL2-IM-0374-0001-0001.jpeg',
#  'NORMAL2-IM-0213-0001.jpeg',
#  'IM-0046-0001.jpeg',
#  'NORMAL2-IM-0105-0001.jpeg',
#  'NORMAL2-IM-0380-0001.jpeg',
#  'IM-0011-0001-0001.jpeg',
#  'NORMAL2-IM-0241-0001.jpeg',
#  'NORMAL2-IM-0131-0001.jpeg',
#  'NORMAL2-IM-0086-0001.jpeg',
#  'IM-0005-0001.jpeg',
#  'NORMAL2-IM-0267-0001.jpeg',
#  'NORMAL2-IM-0110-0001.jpeg',
#  'NORMAL2-IM-0288-0001.jpeg',
#  'NORMAL2-IM-0381-0001.jpeg',
#  'IM-0036-0001.jpeg',
#  'NORMAL2-IM-0280-0001.jpeg',
#  'IM-0016-0001.jpeg',
#  'NORMAL2-IM-0285-0001.jpeg',
#  'NORMAL2-IM-0013-0001.jpeg',
#  'IM-0030-0001.jpeg',
#  'NORMAL2-IM-0317-0001.jpeg',
#  'NORMAL2-IM-0146-0001.jpeg',
#  'NORMAL2-IM-0023-0001.jpeg',
#  'NORMAL2-IM-0219-0001.jpeg',
#  'IM-0025-0001.jpeg',
#  'IM-0037-0001.jpeg',
#  'IM-0099-0001.jpeg',
#  'IM-0083-0001.jpeg',
#  'NORMAL2-IM-0335-0001.jpeg',
#  'NORMAL2-IM-0271-0001.jpeg',
#  'IM-0007-0001.jpeg',
#  'NORMAL2-IM-0331-0001.jpeg',
#  'IM-0039-0001.jpeg',
#  'IM-0027-0001.jpeg',
#  'NORMAL2-IM-0117-0001.jpeg',
#  'NORMAL2-IM-0292-0001.jpeg',
#  'IM-0077-0001.jpeg',
#  'IM-0089-0001.jpeg',
#  'NORMAL2-IM-0196-0001.jpeg',
#  'IM-0033-0001.jpeg',
#  'NORMAL2-IM-0095-0001.jpeg',
#  'IM-0019-0001.jpeg',
#  'NORMAL2-IM-0275-0001.jpeg',
#  'IM-0011-0001.jpeg',
#  'IM-0109-0001.jpeg',
#  'IM-0049-0001.jpeg',
#  'NORMAL2-IM-0279-0001.jpeg',
#  'NORMAL2-IM-0277-0001.jpeg',
#  'NORMAL2-IM-0045-0001.jpeg',
#  'IM-0093-0001.jpeg',
#  'NORMAL2-IM-0029-0001.jpeg',
#  'IM-0023-0001.jpeg',
#  'NORMAL2-IM-0130-0001.jpeg',
#  'NORMAL2-IM-0361-0001.jpeg',
#  'NORMAL2-IM-0233-0001.jpeg',
#  'NORMAL2-IM-0300-0001.jpeg',
#  'NORMAL2-IM-0316-0001.jpeg',
#  'NORMAL2-IM-0060-0001.jpeg',
#  'NORMAL2-IM-0364-0001.jpeg',
#  'NORMAL2-IM-0350-0001.jpeg',
#  'NORMAL2-IM-0347-0001.jpeg',
#  'NORMAL2-IM-0352-0001.jpeg',
#  'IM-0011-0001-0002.jpeg',
#  'NORMAL2-IM-0229-0001.jpeg',
#  'NORMAL2-IM-0359-0001.jpeg',
#  'NORMAL2-IM-0256-0001.jpeg',
#  'NORMAL2-IM-0141-0001.jpeg',
#  'IM-0063-0001.jpeg',
#  'IM-0028-0001.jpeg',
#  'NORMAL2-IM-0325-0001.jpeg',
#  'NORMAL2-IM-0102-0001.jpeg',
#  'NORMAL2-IM-0173-0001-0002.jpeg',
#  'NORMAL2-IM-0372-0001.jpeg',
#  'NORMAL2-IM-0368-0001.jpeg',
#  'IM-0079-0001.jpeg',
#  'NORMAL2-IM-0249-0001.jpeg',
#  'IM-0045-0001.jpeg',
#  'IM-0065-0001.jpeg',
#  'NORMAL2-IM-0312-0001.jpeg',
#  'NORMAL2-IM-0339-0001.jpeg',
#  'NORMAL2-IM-0373-0001.jpeg',
#  'NORMAL2-IM-0354-0001.jpeg',
#  'NORMAL2-IM-0341-0001.jpeg',
#  'NORMAL2-IM-0079-0001.jpeg',
#  'NORMAL2-IM-0107-0001.jpeg',
#  'NORMAL2-IM-0353-0001.jpeg',
#  'NORMAL2-IM-0173-0001-0001.jpeg',
#  'NORMAL2-IM-0238-0001.jpeg',
#  'NORMAL2-IM-0349-0001.jpeg',
#  'NORMAL2-IM-0369-0001.jpeg',
#  'IM-0086-0001.jpeg',
#  'NORMAL2-IM-0323-0001.jpeg',
#  'IM-0073-0001.jpeg',
#  'NORMAL2-IM-0328-0001.jpeg',
#  'NORMAL2-IM-0072-0001.jpeg',
#  'NORMAL2-IM-0304-0001.jpeg',
#  'NORMAL2-IM-0123-0001.jpeg',
#  'NORMAL2-IM-0343-0001.jpeg',
#  'IM-0075-0001.jpeg',
#  'NORMAL2-IM-0329-0001.jpeg',
#  'IM-0087-0001.jpeg',
#  'NORMAL2-IM-0370-0001.jpeg',
#  'IM-0085-0001.jpeg',
#  'IM-0095-0001.jpeg',
#  'IM-0033-0001-0001.jpeg',
#  'NORMAL2-IM-0221-0001.jpeg',
#  'NORMAL2-IM-0251-0001.jpeg',
#  'NORMAL2-IM-0066-0001.jpeg',
#  'IM-0069-0001.jpeg',
#  'NORMAL2-IM-0303-0001.jpeg',
#  'NORMAL2-IM-0338-0001.jpeg',
#  'NORMAL2-IM-0195-0001.jpeg',
#  'NORMAL2-IM-0333-0001.jpeg',
#  'NORMAL2-IM-0150-0001.jpeg',
#  'IM-0010-0001.jpeg']

# %%
predict('/kaggle/input/chest-xray-pneumonia/chest_xray/test/NORMAL/IM-0086-0001.jpeg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
predict('/kaggle/input/chest-xray-pneumonia/chest_xray/test/NORMAL/NORMAL2-IM-0303-0001.jpeg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
